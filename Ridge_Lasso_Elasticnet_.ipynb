# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = sns.load_dataset('mpg')

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
df.drop("name", axis =1 ,inplace = True)

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin
# 0            70     usa
# 1            70     usa
# 2            70     usa
# 3            70     usa
# ...

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 25.0+ KB

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
df.describe(include = 'all')
# Out:
#                mpg   cylinders  displacement  horsepower       weight  \
# count   398.000000  398.000000    398.000000  392.000000   398.000000
# unique         NaN         NaN           NaN         NaN          NaN
# top            NaN         NaN           NaN         NaN          NaN
# freq           NaN         NaN           NaN         NaN          NaN
# mean     23.514573    5.454774    193.425879  104.469388  2970.424623
# std       7.815984    1.701004    104.269838   38.491160   846.841774
# min       9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%      17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%      23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%      29.000000    8.000000    262.000000  126.000000  3608.000000
# max      46.600000    8.000000    455.000000  230.000000  5140.000000
#
#         acceleration  model_year origin
# count     398.000000  398.000000    398
# unique           NaN         NaN      3
# ...

# %%
df['horsepower'].median()
# Out:
# 93.5

# %%
df['horsepower'] = df['horsepower'].fillna(df['horsepower'].median())

# %%
df.isnull()
# Out:
#        mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    False      False         False       False   False         False
# 1    False      False         False       False   False         False
# 2    False      False         False       False   False         False
# 3    False      False         False       False   False         False
# 4    False      False         False       False   False         False
# ..     ...        ...           ...         ...     ...           ...
# 393  False      False         False       False   False         False
# 394  False      False         False       False   False         False
# 395  False      False         False       False   False         False
# 396  False      False         False       False   False         False
# 397  False      False         False       False   False         False
#
#      model_year  origin
# 0         False   False
# 1         False   False
# 2         False   False
# 3         False   False
# ...

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
df.origin.unique()
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %%
df.origin.value_counts()
# Out:
# origin
# usa       249
# japan      79
# europe     70
# Name: count, dtype: int64

# %%
df['origin'] = df['origin'].map({"usa":1, "japan":2, "europe":3})

# %%
df['origin']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 393    1
# 394    3
# 395    1
# 396    1
# 397    1
# Name: origin, Length: 398, dtype: int64

# %%
df.origin.value_counts()
# Out:
# origin
# 1    249
# 2     79
# 3     70
# Name: count, dtype: int64

# %%
X = df.drop('mpg', axis =1)

# %%
y=df['mpg']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=1)

# %%
X_train
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 350          4         105.0        63.0    2215          14.9          81
# 59           4          97.0        54.0    2254          23.5          72
# 120          4         121.0       112.0    2868          15.5          73
# 12           8         400.0       150.0    3761           9.5          70
# 349          4          91.0        68.0    1985          16.0          81
# ..         ...           ...         ...     ...           ...         ...
# 393          4         140.0        86.0    2790          15.6          82
# 255          4         140.0        88.0    2720          15.4          78
# 72           8         304.0       150.0    3892          12.5          72
# 235          4          97.0        75.0    2265          18.2          77
# 37           6         232.0       100.0    3288          15.5          71
#
#      origin
# 350       1
# 59        3
# 120       3
# 12        1
# ...

# %%
X_test
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 174          6         171.0        97.0    2984          14.5          75
# 359          4         141.0        80.0    3230          20.4          81
# 250          8         318.0       140.0    3735          13.2          78
# 274          5         131.0       103.0    2830          15.9          78
# 283          6         232.0        90.0    3265          18.2          79
# ..         ...           ...         ...     ...           ...         ...
# 382          4         108.0        70.0    2245          16.9          82
# 39           8         400.0       175.0    4464          11.5          71
# 171          4         134.0        96.0    2702          13.5          75
# 271          4         156.0       105.0    2745          16.7          78
# 247          4          85.0        70.0    2070          18.6          78
#
#      origin
# 174       1
# 359       3
# 250       1
# 274       3
# ...

# %%
y_train
# Out:
# 350    34.7
# 59     23.0
# 120    19.0
# 12     15.0
# 349    34.1
#        ...
# 393    27.0
# 255    25.1
# 72     15.0
# 235    26.0
# 37     18.0
# Name: mpg, Length: 278, dtype: float64

# %%
y_test
# Out:
# 174    18.0
# 359    28.1
# 250    19.4
# 274    20.3
# 283    20.2
#        ...
# 382    34.0
# 39     14.0
# 171    24.0
# 271    23.2
# 247    39.4
# Name: mpg, Length: 120, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
regression_nodel = LinearRegression()
regression_nodel
# Out:
# LinearRegression()

# %%
regression_nodel.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
for i, col_name in enumerate(X_train.columns):
  print(f"The cofficients for {col_name} is {regression_nodel.coef_[i]}")
# Out:
# The cofficients for cylinders is -0.31761423027992997
# The cofficients for displacement is 0.02623748259907894
# The cofficients for horsepower is -0.018270764913124644
# The cofficients for weight is -0.007487750398361904
# The cofficients for acceleration is 0.050406734619713886
# The cofficients for model_year is 0.8470951427061371
# The cofficients for origin is 1.5190958387975042

# %%
from sklearn.metrics import r2_score
y_pred_linear = regression_nodel.predict(X_test)

# %%
r2_score(y_test,y_pred_linear)
# Out:
# 0.8348001123742284

# %%
#Ridge regression

from sklearn.linear_model import Ridge

# %%
ridge_regressor_model = Ridge(alpha = 100)
ridge_regressor_model.fit(X_train, y_train)
for i, col_name in enumerate(X_train.columns):
  print(f"The cofficient for {col_name} is {ridge_regressor_model.coef_[i]}")
# Out:
# The cofficient for cylinders is -0.10121103813475027
# The cofficient for displacement is 0.01549704723498342
# The cofficient for horsepower is -0.0151541465376744
# The cofficient for weight is -0.007251601127122979
# The cofficient for acceleration is 0.030640385245585478
# The cofficient for model_year is 0.7914981246881714
# The cofficient for origin is 0.7240611102907413

# %%
y_pred = ridge_regressor_model.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# 0.8350365150570258

# %%
#Lasso
from sklearn.linear_model import Lasso

lasso_regressor_model = Lasso(alpha = 0.5)
lasso_regressor_model.fit(X_train, y_train)
for i, col_name in enumerate(X_train.columns):
  print(f"The cofficient for {col_name} is {lasso_regressor_model.coef_[i]}")

#By o/p we can say that even if we remove features cylinders, accleration still we get Accuracy or r2 score 83 as earlier
# Out:
# The cofficient for cylinders is -0.0
# The cofficient for displacement is 0.006208198888300358
# The cofficient for horsepower is -0.011058382987169565
# The cofficient for weight is -0.0069826731680230885
# The cofficient for acceleration is 0.0
# The cofficient for model_year is 0.744654952003819
# The cofficient for origin is 0.0

# %%
y_pred = lasso_regressor_model.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# 0.8277934716635555

# %%
from sklearn.linear_model import ElasticNet

elastic_regression_model = ElasticNet(alpha=0.8, l1_ratio=0.4)
elastic_regression_model.fit(X_train, y_train)
for i, col_name in enumerate(X_train.columns):
    print(f"The coefficient for {col_name} is {elastic_regression_model.coef_[i]}")
# Out:
# The coefficient for cylinders is -0.0
# The coefficient for displacement is 0.007991329781571462
# The coefficient for horsepower is -0.013891824664720713
# The coefficient for weight is -0.006988137750203173
# The coefficient for acceleration is 0.0
# The coefficient for model_year is 0.736838267738092
# The coefficient for origin is 0.20426289739925593

# %%
from sklearn.metrics import r2_score
y_pred = elastic_regression_model.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# 0.8308672338152328

# %%
from sklearn.linear_model import LassoCV
lassocv = LassoCV(cv = 5)
lassocv.fit(X_train, y_train)
y_pred = lassocv.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# 0.8082805983844751
